# %% [markdown]
# # This file is for the purpose of exploring the different top level directories of the lda senate database

# %%
import requests, json
import pandas as pd

base_url = "https://lda.senate.gov/api/v1/"

# %%
# Request top-most level and save as table of contents
table_of_contents = requests.get(base_url).json()
print(json.dumps(table_of_contents,indent=4,sort_keys=True))
# Out:
# {
#     "clients": "https://lda.senate.gov/api/v1/clients/",
#     "constants/contribution/itemtypes": "https://lda.senate.gov/api/v1/constants/contribution/itemtypes/",
#     "constants/filing/filingtypes": "https://lda.senate.gov/api/v1/constants/filing/filingtypes/",
#     "constants/filing/governmententities": "https://lda.senate.gov/api/v1/constants/filing/governmententities/",
#     "constants/filing/lobbyingactivityissues": "https://lda.senate.gov/api/v1/constants/filing/lobbyingactivityissues/",
#     "constants/general/countries": "https://lda.senate.gov/api/v1/constants/general/countries/",
#     "constants/general/states": "https://lda.senate.gov/api/v1/constants/general/states/",
#     "constants/lobbyist/prefixes": "https://lda.senate.gov/api/v1/constants/lobbyist/prefixes/",
#     "constants/lobbyist/suffixes": "https://lda.senate.gov/api/v1/constants/lobbyist/suffixes/",
#     "contributions": "https://lda.senate.gov/api/v1/contributions/",
# ...

# %%
# Produce headers list that contains the different headers from the table of contents 
# (extracted from the keys of the dictionary that was pulled)
headers = list(table_of_contents.keys())
print(headers)
# Out:
# ['filings', 'contributions', 'registrants', 'clients', 'lobbyists', 'constants/filing/filingtypes', 'constants/filing/lobbyingactivityissues', 'constants/filing/governmententities', 'constants/general/countries', 'constants/general/states', 'constants/lobbyist/prefixes', 'constants/lobbyist/suffixes', 'constants/contribution/itemtypes']

# %% [markdown]
# # Explore what each header contains

# %%
# Header 0 - "Filings"
x=0
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# filings
# {
#     "count": 1617958,
#     "next": "https://lda.senate.gov/api/v1/filings/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "affiliated_organizations": [],
#             "client": {
#                 "client_government_entity": null,
#                 "client_id": 987,
#                 "client_self_select": null,
#                 "country": "US",
#                 "country_display": "United States of America",
#                 "effective_date": "1999-01-01",
#                 "general_description": null,
#                 "id": 147688,
#                 "name": "DIGITALTHINK INC",
#                 "ppb_country": "US",
#                 "ppb_country_display": "United States of America",
#                 "ppb_state": "CA",
#                 "ppb_state_display": "California",
#                 "state": "CA",
#                 "state_display": "California",
#                 "url": "https://lda.senate.gov/api/v1/clients/147688/"
# ...

# %%
# Header 1 - "Contributions"
x=1
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# contributions
# {
#     "count": 535039,
#     "next": "https://lda.senate.gov/api/v1/contributions/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "address_1": "1817 Edgehill Drive",
#             "address_2": null,
#             "city": "Alexandria",
#             "comments": null,
#             "contact_name": null,
#             "contribution_items": [
#                 {
#                     "amount": "500.00",
#                     "contribution_type": "feca",
#                     "contribution_type_display": "FECA",
#                     "contributor_name": "FULLER, CAROLYN",
#                     "date": "2008-03-09",
#                     "honoree_name": "Senator Daniel Inouye",
#                     "payee_name": "DAN10"
#                 },
#                 {
#                     "amount": "500.00",
#                     "contribution_type": "feca",
#                     "contribution_type_display": "FECA",
# ...

# %%
# Header 2 - "Registrants"
x=2
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# registrants
# {
#     "count": 15568,
#     "next": "https://lda.senate.gov/api/v1/registrants/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "address_1": "925 L ST   #1404",
#             "address_2": null,
#             "address_3": null,
#             "address_4": null,
#             "city": "SACRAMENTO",
#             "contact_name": "",
#             "contact_telephone": "",
#             "country": "US",
#             "country_display": "United States of America",
#             "description": "12/30/05",
#             "dt_updated": "2022-02-18T16:11:23.828193-05:00",
#             "house_registrant_id": 32323,
#             "id": 11,
#             "name": "A-K ASSOC",
#             "ppb_country": "US",
#             "ppb_country_display": "United States of America",
#             "state": "CA",
#             "state_display": "California",
#             "url": "https://lda.senate.gov/api/v1/registrants/11/",
#             "zip": "95814"
# ...

# %%
# Header 3 - "Clients"
x=3
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# clients
# {
#     "count": 117924,
#     "next": "https://lda.senate.gov/api/v1/clients/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "client_government_entity": null,
#             "client_id": 36,
#             "client_self_select": null,
#             "country": "US",
#             "country_display": "United States of America",
#             "effective_date": "1996-02-14",
#             "general_description": null,
#             "id": 100001,
#             "name": "GOLDEN GATE BRIDGE HIGHWAY & TRANSPORTATION DIST",
#             "ppb_country": "US",
#             "ppb_country_display": "United States of America",
#             "ppb_state": null,
#             "ppb_state_display": null,
#             "registrant": {
#                 "address_1": "925 L ST   #1404",
#                 "address_2": null,
#                 "address_3": null,
#                 "address_4": null,
#                 "city": "SACRAMENTO",
# ...

# %%
# Header 4 - "Lobbyists"
x=4
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# lobbyists
# {
#     "count": 79498,
#     "next": "https://lda.senate.gov/api/v1/lobbyists/?page=2",
#     "previous": null,
#     "results": [
#         {
#             "first_name": "THOMAS",
#             "id": 26645,
#             "last_name": "KONOVALOFF",
#             "middle_name": null,
#             "nickname": null,
#             "prefix": null,
#             "prefix_display": null,
#             "registrant": {
#                 "address_1": "925 L ST   #1404",
#                 "address_2": null,
#                 "address_3": null,
#                 "address_4": null,
#                 "city": "SACRAMENTO",
#                 "contact_name": "",
#                 "contact_telephone": "",
#                 "country": "US",
#                 "country_display": "United States of America",
#                 "description": "12/30/05",
#                 "dt_updated": "2022-02-18T16:11:23.828193-05:00",
#                 "house_registrant_id": 32323,
# ...

# %%
# Header 5 - "Filing Types"
x=5
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# constants/filing/filingtypes
# [
#     {
#         "name": "Registration",
#         "value": "RR"
#     },
#     {
#         "name": "Registration - Amendment",
#         "value": "RA"
#     },
#     {
#         "name": "1st Quarter - Report",
#         "value": "Q1"
#     },
#     {
#         "name": "1st Quarter - Report (No Activity)",
#         "value": "Q1Y"
#     },
#     {
#         "name": "1st Quarter - Termination",
#         "value": "1T"
#     },
#     {
#         "name": "1st Quarter - Termination (No Activity)",
#         "value": "1TY"
#     },
#     {
#         "name": "1st Quarter - Amendment",
#         "value": "1A"
#     },
#     {
#         "name": "1st Quarter - Amendment (No Activity)",
#         "value": "1AY"
#     },
#     {
#         "name": "1st Quarter - Termination Amendment",
#         "value": "1@"
#     },
#     {
#         "name": "1st Quarter - Termination Amendment (No Activity)",
#         "value": "1@Y"
#     },
#     {
# ...

# %%
# Header 6 - "Lobbying Activity Issues"
x=6
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# constants/filing/lobbyingactivityissues
# [
#     {
#         "name": "Accounting",
#         "value": "ACC"
#     },
#     {
#         "name": "Advertising",
#         "value": "ADV"
#     },
#     {
#         "name": "Aerospace",
#         "value": "AER"
#     },
#     {
#         "name": "Agriculture",
#         "value": "AGR"
#     },
#     {
#         "name": "Alcohol and Drug Abuse",
#         "value": "ALC"
#     },
#     {
#         "name": "Animals",
#         "value": "ANI"
#     },
#     {
#         "name": "Apparel/Clothing Industry/Textiles",
#         "value": "APP"
#     },
#     {
#         "name": "Arts/Entertainment",
#         "value": "ART"
#     },
#     {
#         "name": "Automotive Industry",
#         "value": "AUT"
#     },
#     {
#         "name": "Aviation/Airlines/Airports",
#         "value": "AVI"
#     },
#     {
#         "name": "Banking",
#         "value": "BAN"
#     },
#     {
#         "name": "Bankruptcy",
#         "value": "BNK"
#     },
# ...

# %%
# Header 7 - "Government Entities"
x=7
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# constants/filing/governmententities
# [
#     {
#         "id": 211,
#         "name": "Access Board"
#     },
#     {
#         "id": 131,
#         "name": "Administration for Children & Families (ACF)"
#     },
#     {
#         "id": 130,
#         "name": "Administration on Aging"
#     },
#     {
#         "id": 214,
#         "name": "Advisory Council on Historic Preservation (ACHP)"
#     },
#     {
#         "id": 43,
#         "name": "African Development Foundation"
#     },
#     {
#         "id": 132,
#         "name": "Agency for Healthcare Research & Quality (AHRQ)"
#     },
#     {
#         "id": 133,
#         "name": "Agency for Toxic Substances & Disease Registry"
#     },
#     {
#         "id": 23,
#         "name": "Agriculture, Dept of (USDA)"
#     },
#     {
#         "id": 29,
#         "name": "Air Force, Dept of"
#     },
#     {
#         "id": 225,
#         "name": "Alcohol & Tobacco Tax & Trade Bureau (TTB)"
#     },
#     {
#         "id": 104,
# ...

# %%
# Header 12 - "Item Types"
x=12
response = requests.get("https://lda.senate.gov/api/v1/"+str(headers[x])).json()
print(headers[x])
print(json.dumps(response,indent=4,sort_keys=True))
# Out:
# constants/contribution/itemtypes
# [
#     {
#         "name": "FECA",
#         "value": "feca"
#     },
#     {
#         "name": "Honorary Expenses",
#         "value": "he"
#     },
#     {
#         "name": "Meeting Expenses",
#         "value": "me"
#     },
#     {
#         "name": "Presidential Library Expenses",
#         "value": "ple"
#     },
#     {
#         "name": "Presidential Inaugural Committee",
#         "value": "pic"
#     }
# ]

# %%
# Looking at sub headers
# This errors out because not all of the sections have keys within. 
# But we see what we need from the first few. We could create an error handler if we wanted to...
for header in headers:
    url = base_url + header
    response = requests.get(url).json()
    sub_headers = list(response.keys())
    print(header)
    print(sub_headers)
    print("-------------------------------------------------------")
# Out:
# filings
# ['count', 'next', 'previous', 'results']
# -------------------------------------------------------
# contributions
# ['count', 'next', 'previous', 'results']
# -------------------------------------------------------
# registrants
# ['count', 'next', 'previous', 'results']
# -------------------------------------------------------
# clients
# ['count', 'next', 'previous', 'results']
# -------------------------------------------------------
# lobbyists
# ['count', 'next', 'previous', 'results']
# -------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5596\186349230.py in <module>
#       3     url = base_url + header
#       4     response = requests.get(url).json()
# ----> 5     sub_headers = list(response.keys())
#       6     print(header)
#       7     print(sub_headers)
#
# ...
