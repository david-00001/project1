# %%
import requests
import json
import pprint
import pandas as pd

# %%
congress_api_key = "gpqgaxHL9nkyPfQih9oMk1RQCIphB2mmUseNpv5l"

# %%
limit = 950
offset = 2501

# %%
csv_path = "C:/Users/17202/Docu

legislator_info_df = pd.read_csv(csv_path)

# %%
legislator_info_df
# Out:
#       Unnamed: 0 Bio Guide ID                 Name       Party  \
# 0              0      S000062   Sarasin, Ronald A.  Republican
# 1              1      B001305            Budd, Ted  Republican
# 2              2      W000817    Warren, Elizabeth  Democratic
# 3              3      W000802  Whitehouse, Sheldon  Democratic
# 4              4      Y000064          Young, Todd  Republican
# ...          ...          ...                  ...         ...
# 2510        2510      F000229  Flynt, John J., Jr.  Democratic
# 2511        2511      F000218      Flowers, Walter  Democratic
# 2512        2512      F000215     Florio, James J.  Democratic
# 2513        2513      F000209     Flood, Daniel J.  Democratic
# 2514        2514      F000208    Flippo, Ronnie G.  Democratic
#
#                State                                            API URL  \
# 0        Connecticut  https://api.congress.gov/v3/member/S000062?for...
# 1     North Carolina  https://api.congress.gov/v3/member/B001305?for...
# 2      Massachusetts  https://api.congress.gov/v3/member/W000817?for...
# 3       Rhode Island  https://api.congress.gov/v3/member/W000802?for...
# 4            Indiana  https://api.congress.gov/v3/member/Y000064?for...
# ...              ...                                                ...
# 2510         Georgia  https://api.congress.gov/v3/member/F000229?for...
# 2511         Alabama  https://api.congress.gov/v3/member/F000218?for...
# 2512      New Jersey  https://api.congress.gov/v3/member/F000215?for...
# 2513    Pennsylvania  https://api.congress.gov/v3/member/F000209?for...
# 2514         Alabama  https://api.congress.gov/v3/member/F000208?for...
#
#       District Number  Senate End Year  Senate Start Year  House Start Year  \
# 0                 5.0              NaN                NaN            1973.0
# 1                 NaN              NaN             2023.0            2017.0
# 2                 NaN              NaN             2013.0               NaN
# 3                 NaN              NaN             2007.0               NaN
# 4                 NaN              NaN             2017.0            2011.0
# ...               ...              ...                ...               ...
# 2510              6.0              NaN                NaN            1953.0
# 2511              7.0              NaN                NaN            1969.0
# 2512              1.0              NaN                NaN            1975.0
# 2513             11.0              NaN                NaN            1945.0
# 2514              5.0              NaN                NaN            1977.0
#
#       House End Year Current Senator Current House Rep  Years in Senate  \
# 0             1979.0             NaN                 N              NaN
# 1             2023.0               Y                 N              0.0
# 2                NaN               Y               NaN             10.0
# 3                NaN               Y               NaN             16.0
# 4             2017.0               Y                 N              6.0
# ...              ...             ...               ...              ...
# 2510          1979.0             NaN                 N              NaN
# 2511          1979.0             NaN                 N              NaN
# 2512          1991.0             NaN                 N              NaN
# 2513          1947.0             NaN                 N              NaN
# 2514          1991.0             NaN                 N              NaN
#
#       Years in House Served in Senate Served in House
# 0                6.0                N               Y
# 1                6.0                Y               Y
# 2                NaN                Y               N
# 3                NaN                Y               N
# 4                6.0                Y               Y
# ...              ...              ...             ...
# 2510            26.0                N               Y
# 2511            10.0                N               Y
# 2512            16.0                N               Y
# 2513             2.0                N               Y
# 2514            14.0                N               Y
#
# [2515 rows x 17 columns]

# %%
url = f"https://api.congress.gov/v3/member?limit={limit}&offset={offset}&api_key={congress_api_key}"

response = requests.get(url).json()
# pprint.pprint(response)

# %%
members_num = len(response["members"])
members=[]

# %%
members_num
# Out:
# 14

# %%
for i in range(members_num):
    ID = response["members"][i]["member"]["bioguideId"]
    members.append(ID)
# print(members)

# %%
gender = []

for x in members: 
    
    url = f"https://api.congress.gov/v3/member/{x}?limit={limit}&offset={offset}&api_key={congress_api_key}"
    response = requests.get(url).json()
    member = response["member"]
    name = member["invertedOrderName"]

    honorific_name = member["honorificName"] if "honorificName" in member else None

    if honorific_name:
        if honorific_name == "Mr.":
            sex = "M"
        elif honorific_name in ("Mrs.", "Ms.", "Miss"):
            sex = "F"
        else:
            sex = "U"
    else:
        sex = "U"

    gender.append({"Name" :name,
                   "Gender": sex})

# %%
print(gender)
# Out:
# [{'Name': 'Fountain, L. H.', 'Gender': 'U'}, {'Name': 'Forsythe, Edwin B.', 'Gender': 'U'}, {'Name': 'Ford, William D.', 'Gender': 'U'}, {'Name': 'Ford, Harold E.', 'Gender': 'U'}, {'Name': 'Ford, Gerald R., Jr.', 'Gender': 'U'}, {'Name': 'Forbes, Michael P.', 'Gender': 'U'}, {'Name': 'Foley, Thomas S.', 'Gender': 'U'}, {'Name': 'Foley, Mark', 'Gender': 'U'}, {'Name': 'Foglietta, Thomas M.', 'Gender': 'U'}, {'Name': 'Flynt, John J., Jr.', 'Gender': 'U'}, {'Name': 'Flowers, Walter', 'Gender': 'U'}, {'Name': 'Florio, James J.', 'Gender': 'U'}, {'Name': 'Flood, Daniel J.', 'Gender': 'U'}, {'Name': 'Flippo, Ronnie G.', 'Gender': 'U'}]

# %%
congress_gender_df = pd.DataFrame(gender)

# %%
congress_gender_df
# Out:
#                     Name Gender
# 0        Fountain, L. H.      U
# 1     Forsythe, Edwin B.      U
# 2       Ford, William D.      U
# 3        Ford, Harold E.      U
# 4   Ford, Gerald R., Jr.      U
# 5     Forbes, Michael P.      U
# 6       Foley, Thomas S.      U
# 7            Foley, Mark      U
# 8   Foglietta, Thomas M.      U
# 9    Flynt, John J., Jr.      U
# 10       Flowers, Walter      U
# 11      Florio, James J.      U
# 12      Flood, Daniel J.      U
# 13     Flippo, Ronnie G.      U

# %%
merged_df = pd.merge(legislator_info_df, congress_gender_df, on = "Name" )

# %%
merged_df
# Out:
#     Unnamed: 0 Bio Guide ID                  Name       Party           State  \
# 0         2501      F000319       Fountain, L. H.  Democratic  North Carolina
# 1         2502      F000286    Forsythe, Edwin B.  Republican      New Jersey
# 2         2503      F000270      Ford, William D.  Democratic        Michigan
# 3         2504      F000261       Ford, Harold E.  Democratic       Tennessee
# 4         2505      F000260  Ford, Gerald R., Jr.  Republican        Michigan
# 5         2506      F000257    Forbes, Michael P.  Democratic        New York
# 6         2507      F000239      Foley, Thomas S.  Democratic      Washington
# 7         2508      F000238           Foley, Mark  Republican         Florida
# 8         2509      F000235  Foglietta, Thomas M.  Democratic    Pennsylvania
# 9         2510      F000229   Flynt, John J., Jr.  Democratic         Georgia
# 10        2511      F000218       Flowers, Walter  Democratic         Alabama
# 11        2512      F000215      Florio, James J.  Democratic      New Jersey
# 12        2513      F000209      Flood, Daniel J.  Democratic    Pennsylvania
# 13        2514      F000208     Flippo, Ronnie G.  Democratic         Alabama
#
#                                               API URL  District Number  \
# 0   https://api.congress.gov/v3/member/F000319?for...              2.0
# 1   https://api.congress.gov/v3/member/F000286?for...             13.0
# 2   https://api.congress.gov/v3/member/F000270?for...             13.0
# 3   https://api.congress.gov/v3/member/F000261?for...              9.0
# 4   https://api.congress.gov/v3/member/F000260?for...              5.0
# 5   https://api.congress.gov/v3/member/F000257?for...              1.0
# 6   https://api.congress.gov/v3/member/F000239?for...              5.0
# 7   https://api.congress.gov/v3/member/F000238?for...             16.0
# 8   https://api.congress.gov/v3/member/F000235?for...              1.0
# 9   https://api.congress.gov/v3/member/F000229?for...              6.0
# 10  https://api.congress.gov/v3/member/F000218?for...              7.0
# 11  https://api.congress.gov/v3/member/F000215?for...              1.0
# 12  https://api.congress.gov/v3/member/F000209?for...             11.0
# 13  https://api.congress.gov/v3/member/F000208?for...              5.0
#
#     Senate End Year  Senate Start Year  House Start Year  House End Year  \
# 0               NaN                NaN            1953.0          1983.0
# 1               NaN                NaN            1969.0          1985.0
# 2               NaN                NaN            1965.0          1995.0
# 3               NaN                NaN            1975.0          1997.0
# 4               NaN                NaN            1949.0          1975.0
# 5               NaN                NaN            1995.0          2001.0
# 6               NaN                NaN            1965.0          1995.0
# 7               NaN                NaN            1995.0          2007.0
# 8               NaN                NaN            1981.0          1999.0
# 9               NaN                NaN            1953.0          1979.0
# 10              NaN                NaN            1969.0          1979.0
# 11              NaN                NaN            1975.0          1991.0
# 12              NaN                NaN            1945.0          1947.0
# 13              NaN                NaN            1977.0          1991.0
#
#    Current Senator Current House Rep  Years in Senate  Years in House  \
# 0              NaN                 N              NaN            30.0
# 1              NaN                 N              NaN            16.0
# 2              NaN                 N              NaN            30.0
# 3              NaN                 N              NaN            22.0
# 4              NaN                 N              NaN            26.0
# 5              NaN                 N              NaN             6.0
# 6              NaN                 N              NaN            30.0
# 7              NaN                 N              NaN            12.0
# 8              NaN                 N              NaN            18.0
# 9              NaN                 N              NaN            26.0
# 10             NaN                 N              NaN            10.0
# 11             NaN                 N              NaN            16.0
# 12             NaN                 N              NaN             2.0
# 13             NaN                 N              NaN            14.0
#
#    Served in Senate Served in House Gender
# 0                 N               Y      U
# 1                 N               Y      U
# 2                 N               Y      U
# 3                 N               Y      U
# 4                 N               Y      U
# 5                 N               Y      U
# 6                 N               Y      U
# 7                 N               Y      U
# 8                 N               Y      U
# 9                 N               Y      U
# 10                N               Y      U
# 11                N               Y      U
# 12                N               Y      U
# 13                N               Y      U

# %%
bill_member =[]

for z in members:
    url = f"https://api.congress.gov/v3/member/{z}?limit={limit}&offset={offset}&api_key={congress_api_key}"
    response = requests.get(url).json()
    member = response["member"]
    name = member["invertedOrderName"]
    
    bills = member["sponsoredLegislation"]["count"] if "sponsoredLegislation" in member else None
    
    bill_member.append({"Name" : name,
                       "Bill" : bills})

# %%
print(bill_member)
# Out:
# [{'Name': 'Fountain, L. H.', 'Bill': 61}, {'Name': 'Forsythe, Edwin B.', 'Bill': 194}, {'Name': 'Ford, William D.', 'Bill': 278}, {'Name': 'Ford, Harold E.', 'Bill': 126}, {'Name': 'Ford, Gerald R., Jr.', 'Bill': 29}, {'Name': 'Forbes, Michael P.', 'Bill': 52}, {'Name': 'Foley, Thomas S.', 'Bill': 333}, {'Name': 'Foley, Mark', 'Bill': 149}, {'Name': 'Foglietta, Thomas M.', 'Bill': 84}, {'Name': 'Flynt, John J., Jr.', 'Bill': 127}, {'Name': 'Flowers, Walter', 'Bill': 57}, {'Name': 'Florio, James J.', 'Bill': 273}, {'Name': 'Flood, Daniel J.', 'Bill': 107}, {'Name': 'Flippo, Ronnie G.', 'Bill': 63}]

# %%
bill_congress = pd.DataFrame(bill_member)

bill_congress
# Out:
#                     Name  Bill
# 0        Fountain, L. H.    61
# 1     Forsythe, Edwin B.   194
# 2       Ford, William D.   278
# 3        Ford, Harold E.   126
# 4   Ford, Gerald R., Jr.    29
# 5     Forbes, Michael P.    52
# 6       Foley, Thomas S.   333
# 7            Foley, Mark   149
# 8   Foglietta, Thomas M.    84
# 9    Flynt, John J., Jr.   127
# 10       Flowers, Walter    57
# 11      Florio, James J.   273
# 12      Flood, Daniel J.   107
# 13     Flippo, Ronnie G.    63

# %%
combined_df = pd.merge(merged_df, bill_congress, on="Name")

# %%
combined_df
# Out:
#     Unnamed: 0 Bio Guide ID                  Name       Party           State  \
# 0         2501      F000319       Fountain, L. H.  Democratic  North Carolina
# 1         2502      F000286    Forsythe, Edwin B.  Republican      New Jersey
# 2         2503      F000270      Ford, William D.  Democratic        Michigan
# 3         2504      F000261       Ford, Harold E.  Democratic       Tennessee
# 4         2505      F000260  Ford, Gerald R., Jr.  Republican        Michigan
# 5         2506      F000257    Forbes, Michael P.  Democratic        New York
# 6         2507      F000239      Foley, Thomas S.  Democratic      Washington
# 7         2508      F000238           Foley, Mark  Republican         Florida
# 8         2509      F000235  Foglietta, Thomas M.  Democratic    Pennsylvania
# 9         2510      F000229   Flynt, John J., Jr.  Democratic         Georgia
# 10        2511      F000218       Flowers, Walter  Democratic         Alabama
# 11        2512      F000215      Florio, James J.  Democratic      New Jersey
# 12        2513      F000209      Flood, Daniel J.  Democratic    Pennsylvania
# 13        2514      F000208     Flippo, Ronnie G.  Democratic         Alabama
#
#                                               API URL  District Number  \
# 0   https://api.congress.gov/v3/member/F000319?for...              2.0
# 1   https://api.congress.gov/v3/member/F000286?for...             13.0
# 2   https://api.congress.gov/v3/member/F000270?for...             13.0
# 3   https://api.congress.gov/v3/member/F000261?for...              9.0
# 4   https://api.congress.gov/v3/member/F000260?for...              5.0
# 5   https://api.congress.gov/v3/member/F000257?for...              1.0
# 6   https://api.congress.gov/v3/member/F000239?for...              5.0
# 7   https://api.congress.gov/v3/member/F000238?for...             16.0
# 8   https://api.congress.gov/v3/member/F000235?for...              1.0
# 9   https://api.congress.gov/v3/member/F000229?for...              6.0
# 10  https://api.congress.gov/v3/member/F000218?for...              7.0
# 11  https://api.congress.gov/v3/member/F000215?for...              1.0
# 12  https://api.congress.gov/v3/member/F000209?for...             11.0
# 13  https://api.congress.gov/v3/member/F000208?for...              5.0
#
#     Senate End Year  Senate Start Year  House Start Year  House End Year  \
# 0               NaN                NaN            1953.0          1983.0
# 1               NaN                NaN            1969.0          1985.0
# 2               NaN                NaN            1965.0          1995.0
# 3               NaN                NaN            1975.0          1997.0
# 4               NaN                NaN            1949.0          1975.0
# 5               NaN                NaN            1995.0          2001.0
# 6               NaN                NaN            1965.0          1995.0
# 7               NaN                NaN            1995.0          2007.0
# 8               NaN                NaN            1981.0          1999.0
# 9               NaN                NaN            1953.0          1979.0
# 10              NaN                NaN            1969.0          1979.0
# 11              NaN                NaN            1975.0          1991.0
# 12              NaN                NaN            1945.0          1947.0
# 13              NaN                NaN            1977.0          1991.0
#
#    Current Senator Current House Rep  Years in Senate  Years in House  \
# 0              NaN                 N              NaN            30.0
# 1              NaN                 N              NaN            16.0
# 2              NaN                 N              NaN            30.0
# 3              NaN                 N              NaN            22.0
# 4              NaN                 N              NaN            26.0
# 5              NaN                 N              NaN             6.0
# 6              NaN                 N              NaN            30.0
# 7              NaN                 N              NaN            12.0
# 8              NaN                 N              NaN            18.0
# 9              NaN                 N              NaN            26.0
# 10             NaN                 N              NaN            10.0
# 11             NaN                 N              NaN            16.0
# 12             NaN                 N              NaN             2.0
# 13             NaN                 N              NaN            14.0
#
#    Served in Senate Served in House Gender  Bill
# 0                 N               Y      U    61
# 1                 N               Y      U   194
# 2                 N               Y      U   278
# 3                 N               Y      U   126
# 4                 N               Y      U    29
# 5                 N               Y      U    52
# 6                 N               Y      U   333
# 7                 N               Y      U   149
# 8                 N               Y      U    84
# 9                 N               Y      U   127
# 10                N               Y      U    57
# 11                N               Y      U   273
# 12                N               Y      U   107
# 13                N               Y      U    63

# %%
combined_df.to_csv("Congress_Gender_2514.csv", index=False)
