# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv("Congress_Gender_250.csv")
df2 = pd.read_csv("Congress_Gender_500.csv")
df3 = pd.read_csv("Congress_Gender_750.csv")
df4 = pd.read_csv("Congress_Gender_1000.csv")
df5 = pd.read_csv("Congress_Gender_1250.csv")
df6 = pd.read_csv("Congress_Gender_1500.csv")
df7 = pd.read_csv("Congress_Gender_1750.csv")
df8 = pd.read_csv("Congress_Gender_2000.csv")
df9 = pd.read_csv("Congress_Gender_2250.csv")
df10 = pd.read_csv("Congress_Gender_2500.csv")
df11 = pd.read_csv("Congress_Gender_2514.csv")

# %%
gender_df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11])

# %%
gender_df
# Out:
#     Unnamed: 0 Bio Guide ID                 Name       Party           State  \
# 0            0      S000062   Sarasin, Ronald A.  Republican     Connecticut
# 1            1      B001305            Budd, Ted  Republican  North Carolina
# 2            2      W000817    Warren, Elizabeth  Democratic   Massachusetts
# 3            3      W000802  Whitehouse, Sheldon  Democratic    Rhode Island
# 4            4      Y000064          Young, Todd  Republican         Indiana
# ..         ...          ...                  ...         ...             ...
# 9         2510      F000229  Flynt, John J., Jr.  Democratic         Georgia
# 10        2511      F000218      Flowers, Walter  Democratic         Alabama
# 11        2512      F000215     Florio, James J.  Democratic      New Jersey
# 12        2513      F000209     Flood, Daniel J.  Democratic    Pennsylvania
# 13        2514      F000208    Flippo, Ronnie G.  Democratic         Alabama
#
#                                               API URL  District Number  \
# 0   https://api.congress.gov/v3/member/S000062?for...              5.0
# 1   https://api.congress.gov/v3/member/B001305?for...              NaN
# 2   https://api.congress.gov/v3/member/W000817?for...              NaN
# 3   https://api.congress.gov/v3/member/W000802?for...              NaN
# 4   https://api.congress.gov/v3/member/Y000064?for...              NaN
# ..                                                ...              ...
# 9   https://api.congress.gov/v3/member/F000229?for...              6.0
# 10  https://api.congress.gov/v3/member/F000218?for...              7.0
# 11  https://api.congress.gov/v3/member/F000215?for...              1.0
# 12  https://api.congress.gov/v3/member/F000209?for...             11.0
# 13  https://api.congress.gov/v3/member/F000208?for...              5.0
#
#     Senate End Year  Senate Start Year  House Start Year  House End Year  \
# 0               NaN                NaN            1973.0          1979.0
# 1               NaN             2023.0            2017.0          2023.0
# 2               NaN             2013.0               NaN             NaN
# 3               NaN             2007.0               NaN             NaN
# 4               NaN             2017.0            2011.0          2017.0
# ..              ...                ...               ...             ...
# 9               NaN                NaN            1953.0          1979.0
# 10              NaN                NaN            1969.0          1979.0
# 11              NaN                NaN            1975.0          1991.0
# 12              NaN                NaN            1945.0          1947.0
# 13              NaN                NaN            1977.0          1991.0
#
#    Gender   Bill Current Senator Current House Rep  Years in Senate  \
# 0       U   85.0             NaN               NaN              NaN
# 1       M  131.0             NaN               NaN              NaN
# 2       F  545.0             NaN               NaN              NaN
# 3       M  551.0             NaN               NaN              NaN
# 4       M  312.0             NaN               NaN              NaN
# ..    ...    ...             ...               ...              ...
# 9       U  127.0             NaN                 N              NaN
# 10      U   57.0             NaN                 N              NaN
# 11      U  273.0             NaN                 N              NaN
# 12      U  107.0             NaN                 N              NaN
# 13      U   63.0             NaN                 N              NaN
#
#     Years in House Served in Senate Served in House
# 0              NaN              NaN             NaN
# 1              NaN              NaN             NaN
# 2              NaN              NaN             NaN
# 3              NaN              NaN             NaN
# 4              NaN              NaN             NaN
# ..             ...              ...             ...
# 9             26.0                N               Y
# 10            10.0                N               Y
# 11            16.0                N               Y
# 12             2.0                N               Y
# 13            14.0                N               Y
#
# [2522 rows x 19 columns]
