# %%
import requests,json,pprint
import pandas as pd
import pprint
from api_keys import congress_gov_key
#from cdg_client import CDGClient
#client = CDGClient(congress_gov_key)

#headers = {f"Authorization: Token {lda_senate_api_key}"}

url = f"https://api.congress.gov/v3/member?api_key={congress_gov_key}"
response = requests.get(url).json()
pprint.pprint(response)
# Out:
# {'members': [{'member': {'bioguideId': 'W000817',
#                          'depiction': {'attribution': '<a '
#                                                       'href="http://www.senate.gov/artandhistory/history/common/generic/Photo_Collection_of_the_Senate_Historical_Office.htm">Courtesy '
#                                                       'U.S. Senate Historical '
#                                                       'Office</a>',
#                                        'imageUrl': 'https://www.congress.gov/img/member/w000817_200.jpg'},
#                          'name': 'Warren, Elizabeth',
#                          'party': 'Democratic',
#                          'served': {'Senate': [{'start': 2013}]},
#                          'state': 'Massachusetts',
#                          'url': 'https://api.congress.gov/v3/member/W000817?format=json'}},
#              {'member': {'bioguideId': 'W000802',
#                          'depiction': {'attribution': '<a '
# ...
